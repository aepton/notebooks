# %%
import os
import requests
import time

from csv import DictReader, DictWriter
from datetime import datetime
from geopy.distance import distance
from io import StringIO
from lxml import etree

DARK_SKY_API_KEY = os.environ.get('DARK_SKY_API_KEY', '')
DARK_SKY_FORECAST_BASE = 'https://api.darksky.net/forecast/{api_key}/{latitude},{longitude}'
DEPART_LAT = 47.612679
DEPART_LON = -122.30115
GOOGLE_MAPS_DIRECTIONS_API_KEY = os.environ.get('GOOGLE_MAPS_DIRECTIONS_API_KEY', '')
NUM_DAYS_PAST_TODAY = 3  # Set to 0, along with NUM_HOURS_PAST_MIDNIGHT_TO_LEAVE, to get values for right now
NUM_HOURS_PAST_MIDNIGHT_TO_LEAVE = 9
NUM_HOURS_TO_DRIVE = 1.5

# %%
def get_forecast_for_coords(lat, lon):
    url = DARK_SKY_FORECAST_BASE.format(api_key=DARK_SKY_API_KEY, latitude=lat, longitude=lon)
    try:
        response = requests.get(url).json()
    except:
        print('Error getting URL {}'.format(url))
        return {
            'forecast_date_for': '',
            'forecast_timestamp': 0,
            'forecast_text': '',
            'cloud_cover': 1
        }
    forecast = response['daily']['data'][NUM_DAYS_PAST_TODAY]
    forecast_date_for = datetime.fromtimestamp(int(forecast['time'])).strftime('%a, %b %d, %Y')
    forecast_text = generate_text_from_forecast(forecast)
    return {
        'forecast_date_for': forecast_date_for,
        'forecast_timestamp': int(forecast['time']),
        'forecast_text': forecast_text,
        'cloud_cover': float(forecast['cloudCover'])
    }

# %%
def generate_text_from_forecast(forecast):
    forecast['cloudCoverPct'] = 100. * forecast['cloudCover']
    time_fmt = '%H:%M:%S'
    forecast['sunriseParsedTime'] = datetime.fromtimestamp(int(forecast['sunriseTime'])).strftime(time_fmt)
    forecast['sunsetParsedTime'] = datetime.fromtimestamp(int(forecast['sunsetTime'])).strftime(time_fmt)
    try:
        forecast['precipMaxParsedTime'] = datetime.fromtimestamp(
            int(forecast['precipIntensityMaxTime'])).strftime(time_fmt)
    except:
        forecast['precipMaxParsedTime'] = '(no max time)'
    if not forecast.get('precipAccumulation', None):
        forecast['precipAccumulation'] = 0
    forecast['precipChance'] = 100. * forecast['precipProbability']
    forecast['precipString'] = ''
    if forecast.get('precipType', None):
        forecast['precipString'] = (
            '\n{precipChance:.1f}% chance of {precipType}; maximum intensity at'.format(**forecast) +
            ' {precipMaxParsedTime}, with {precipAccumulation} inches of snow expected all day'.format(**forecast))
    if not forecast.get('visibility', None):
        forecast['visibility'] = ''
    forecast['summary'] = forecast['summary'].encode('utf-8', 'ignore')

    return """{summary}
High: will feel like {apparentTemperatureHigh} degrees F
Low: will feel like {apparentTemperatureLow} degrees F{precipString}
Cloud cover will be {cloudCoverPct:.0f}%
UV will be {uvIndex} out of 12
Wind speed will be {windSpeed} mph
Visibility will be {visibility} miles
Sun will rise at {sunriseParsedTime} and set at {sunsetParsedTime}
""".format(**forecast)

# %%
def extract_info_from_wta_result(fetch_result):
    parser = etree.HTMLParser()
    tree = etree.parse(StringIO(fetch_result), parser)
    lat = tree.xpath('//*[@id="trailhead-map"]/div[3]/span[1]')
    lon = tree.xpath('//*[@id="trailhead-map"]/div[3]/span[2]')
    name = tree.xpath('//*[@id="hike-top"]/h1')
    region = tree.xpath('//*[@id="hike-region"]/span')
    length = tree.xpath('//*[@id="distance"]/span')
    rating = tree.xpath('//*[@id="rating-stars-view-trail-rating"]/div/div[1]/div')
    height_gain = tree.xpath('//*[@id="hike-stats"]/div[3]/div[1]/span')
    return {
        'lat': float(lat[0].text) if lat else None,
        'lon': float(lon[0].text) if lon else None,
        'name': name[0].text if name else '',
        'region': region[0].text if region else '',
        'length': length[0].text if length else '',
        'rating': rating[0].text if rating else '',
        'height_gain': height_gain[0].text if height_gain else ''
    }

# %%
def get_travel_time_from_point_to_point(start_coords, end_coords, depart_time):
    url = ('https://maps.googleapis.com/maps/api/directions/json?' +
           'origin={0},{1}&'.format(start_coords['lat'], start_coords['lon']) +
           'destination={0},{1}&'.format(end_coords['lat'], end_coords['lon']) +
           'units=imperial&departure_time={0}&'.format(depart_time) +
           'traffic_model=best_guess&key={0}'.format(GOOGLE_MAPS_DIRECTIONS_API_KEY))
    response = requests.get(url).json()
    
    try:
        distance_meters = response['routes'][0]['legs'][0]['distance']['value']
        duration_seconds = response['routes'][0]['legs'][0]['duration_in_traffic']['value']
    except Exception as e:
        print('Error fetching route: {0} - URL was {1}'.format(e, url))
        return {'distance': None, 'duration': None, 'duration_seconds': None}
    
    # First, grab number of hours and remainder in seconds
    divmod_hours = divmod(duration_seconds, 60*60)
    
    # Now, convert remainder in seconds into minutes and seconds
    divmod_minutes = divmod(divmod_hours[1], 60)
    
    return {
        'distance': distance_meters * 0.000621371,
        'duration': '{0}:{1}:{2}'.format(
            str(divmod_hours[0]).zfill(2), str(divmod_minutes[0]).zfill(2), str(divmod_minutes[1]).zfill(2)),
        'duration_seconds': duration_seconds
    }

# %%
def load_hike_data(force_refetch=False):
    hikes = []
    
    if not force_refetch:
        with open('snowshoe_hikes.csv') as fh:
            reader = DictReader(fh)
            [hikes.append(hike) for hike in reader]
    
    if not len(hikes) or force_refetch:
        with open('snowshoe_urls.txt') as fh:
            for url in fh.readlines():
                response = requests.get(url)
                
                try:
                    info = extract_info_from_wta_result(response.text)
                    info['url'] = url
                except Exception as e:
                    print('Error processing response for {0} - {1}, skipping'.format(hike, e))
                    continue
                
                hikes.append(info)
    return hikes

def write_hike_data(hikes):
    header = ['lat', 'lon', 'name', 'region', 'height_gain', 'length', 'rating', 'url']

    with open('snowshoe_hikes.csv', 'w+') as fh:
        writer = DictWriter(fh, sorted(header))
        writer.writeheader()
        writer.writerows([{key: h[key] for key in header} for h in hikes])

# %%
results = []
snowshoe_hikes = load_hike_data()

if False:  # Enable to save new hike data
    write_hike_data(snowshoe_hikes)

print('Found {0} hikes'.format(len(snowshoe_hikes)))

distance_cutoff = NUM_HOURS_TO_DRIVE * 75.

for hike in snowshoe_hikes:
    if not hike['lat'] or not hike['lon']:
        continue
    
    dist = distance((DEPART_LAT, DEPART_LON), (float(hike['lat']), float(hike['lon']))).miles
    if dist >= distance_cutoff:
        print('Distance is too far - {0} miles'.format(dist))
        continue
    
    try:
        forecast = get_forecast_for_coords(hike['lat'], hike['lon'])
        hike.update(forecast)
    except Exception as e:
        print('Error getting forecast for {0} - {1}, skipping'.format(hike, e))
        continue

    depart_time = forecast['forecast_timestamp'] + 60 * 60 * NUM_HOURS_PAST_MIDNIGHT_TO_LEAVE
    if NUM_DAYS_PAST_TODAY == 0 and NUM_HOURS_PAST_MIDNIGHT_TO_LEAVE == 0:
        depart_time = int(time.time()) + 60 * 5  # Leave 5 minutes in future to allow GMaps API to work
    
    try:
        route_info = get_travel_time_from_point_to_point(
            {'lat': DEPART_LAT, 'lon': DEPART_LON}, {'lat': hike['lat'], 'lon': hike['lon']}, depart_time)
        hike.update(route_info)
    except Exception as e:
        print('Error getting travel info for {0} - {1}, skipping'.format(hike, e))
        continue

    if route_info['distance']:
        results.append(hike)
# Out:
# Found 132 hikes
# Distance is too far - 238.98704304 miles
# Distance is too far - 224.383695091 miles
# Distance is too far - 190.047836667 miles
# Distance is too far - 242.966656129 miles
# Error fetching route: list index out of range - URL was https://maps.googleapis.com/maps/api/directions/json?origin=47.612679,-122.30115&destination=48.581,-121.5614&units=imperial&departure_time=1520182800&traffic_model=best_guess&key=AIzaSyAQ44i3QF3MH78H0tcxegOzp-TgQkxNi9U

# %%
cutoff = 60 * 60 * NUM_HOURS_TO_DRIVE

print('Found {0} hike candidates'.format(len(results)))

for hike in filter(
        lambda x: x['duration_seconds'] <= cutoff, sorted(results, key=lambda k: float(k['cloud_cover']), reverse=False)):
    title_string = 'Forecast for {name} ({region}) for {forecast_date_for}:'.format(**hike)
    info_string = 'Hike is {length}; gains {height_gain} feet; and has {rating} stars'.format(**hike)
    route_string = 'Drive will take {duration} to cover {distance:.2f} miles'.format(**hike)
    print('{0}\n{1}\n{2}\n{3}\n{4}\n-----'.format(
        title_string, hike['url'], info_string, route_string, hike['forecast_text']))
# Out:
# Found 105 hike candidates
# Forecast for Amabilis Mountain Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/amabilis-mt
#
# Hike is 9.5 miles, roundtrip; gains 2100 feet; and has 3.00 out of 5 stars
# Drive will take 01:02:17 to cover 62.75 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 36.41 degrees F
# Low: will feel like 30.68 degrees F
# 27.0% chance of snow; maximum intensity at 17:00:00, with 0.732 inches of snow expected all day
# Cloud cover will be 69%
# UV will be 1 out of 12
# Wind speed will be 2.45 mph
# Visibility will be 6.47 miles
# Sun will rise at 06:40:22 and set at 17:56:03
#
# -----
# Forecast for Miller River Road Snowshoe (Central Cascades) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/miller-river-road-backcountry-ski
#
# Hike is 7.4 miles, roundtrip; gains 700 feet; and has 0.00 out of 5 stars
# Drive will take 01:18:49 to cover 63.51 miles
# Foggy in the morning.
# High: will feel like 42.92 degrees F
# Low: will feel like 35.9 degrees F
# 36.0% chance of snow; maximum intensity at 03:00:00, with 0.452 inches of snow expected all day
# Cloud cover will be 72%
# UV will be 1 out of 12
# Wind speed will be 2.4 mph
# Visibility will be 4.82 miles
# Sun will rise at 06:41:10 and set at 17:56:08
#
# -----
# Forecast for Lake Kelcema Snowshoe (North Cascades) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/kelcema-lake-snowshoe
#
# Hike is 10.0 miles, roundtrip; gains 1600 feet; and has 3.00 out of 5 stars
# Drive will take 01:29:04 to cover 66.57 miles
# Light snow in the morning.
# High: will feel like 39.93 degrees F
# Low: will feel like 31.05 degrees F
# 39.0% chance of snow; maximum intensity at 04:00:00, with 0.849 inches of snow expected all day
# Cloud cover will be 73%
# UV will be 1 out of 12
# Wind speed will be 2.69 mph
# Visibility will be 3.92 miles
# Sun will rise at 06:42:07 and set at 17:56:25
#
# -----
# Forecast for Keechelus Ridge Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/keechelus-ridge-snowshoe
#
# Hike is 6.4 miles, roundtrip; gains 2100 feet; and has 1.50 out of 5 stars
# Drive will take 01:02:51 to cover 63.19 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 36.79 degrees F
# Low: will feel like 31.36 degrees F
# 29.0% chance of snow; maximum intensity at 17:00:00, with 0.817 inches of snow expected all day
# Cloud cover will be 73%
# UV will be 1 out of 12
# Wind speed will be 2.4 mph
# Visibility will be 6.19 miles
# Sun will rise at 06:40:32 and set at 17:56:10
#
# -----
# Forecast for Marten Creek Snowshoe (North Cascades) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/marten-creek-snowshoe
#
# Hike is 7.5 miles, roundtrip; gains 1300 feet; and has 2.50 out of 5 stars
# Drive will take 01:23:50 to cover 63.77 miles
# Foggy in the morning.
# High: will feel like 40.24 degrees F
# Low: will feel like 31.26 degrees F
# 40.0% chance of snow; maximum intensity at 04:00:00, with 0.757 inches of snow expected all day
# Cloud cover will be 74%
# UV will be 1 out of 12
# Wind speed will be 2.75 mph
# Visibility will be 4.32 miles
# Sun will rise at 06:42:19 and set at 17:56:39
#
# -----
# Forecast for Mount Pilchuck Snowshoe (North Cascades) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/mount-pilchuck-snowshoe
#
# Hike is 11.0 miles, roundtrip; gains 2600 feet; and has 3.33 out of 5 stars
# Drive will take 01:16:59 to cover 57.15 miles
# Foggy in the morning.
# High: will feel like 39.48 degrees F
# Low: will feel like 30.76 degrees F
# 41.0% chance of snow; maximum intensity at 17:00:00, with 0.493 inches of snow expected all day
# Cloud cover will be 75%
# UV will be 1 out of 12
# Wind speed will be 3 mph
# Visibility will be 6.09 miles
# Sun will rise at 06:43:02 and set at 17:57:21
#
# -----
# Forecast for Mallardy Ridge Snowshoe (North Cascades) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/mallardy-ridge-snowshoe
#
# Hike is 10.0 miles, roundtrip; gains 1900 feet; and has 3.00 out of 5 stars
# Drive will take 01:21:37 to cover 62.48 miles
# Foggy in the morning.
# High: will feel like 41.33 degrees F
# Low: will feel like 31.9 degrees F
# 40.0% chance of snow; maximum intensity at 04:00:00, with 0.646 inches of snow expected all day
# Cloud cover will be 75%
# UV will be 1 out of 12
# Wind speed will be 2.78 mph
# Visibility will be 4.54 miles
# Sun will rise at 06:42:25 and set at 17:56:46
#
# -----
# Forecast for Heather Lake Snowshoe (North Cascades) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/heather-lake-snowshoe
#
# Hike is 4.6 miles, roundtrip; gains 1100 feet; and has 3.17 out of 5 stars
# Drive will take 01:15:05 to cover 56.65 miles
# Foggy in the morning.
# High: will feel like 39.93 degrees F
# Low: will feel like 31.2 degrees F
# 41.0% chance of snow; maximum intensity at 17:00:00, with 0.423 inches of snow expected all day
# Cloud cover will be 75%
# UV will be 1 out of 12
# Wind speed will be 2.99 mph
# Visibility will be 5.94 miles
# Sun will rise at 06:43:00 and set at 17:57:19
#
# -----
# Forecast for East Fork Foss River Snowshoe (Central Cascades) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/east-fork-foss-river-snowshoe
#
# Hike is 13.6 miles, roundtrip; gains 1200 feet; and has 4.00 out of 5 stars
# Drive will take 01:26:28 to cover 69.28 miles
# Foggy in the morning.
# High: will feel like 42.27 degrees F
# Low: will feel like 34.68 degrees F
# 34.0% chance of snow; maximum intensity at 17:00:00, with 0.693 inches of snow expected all day
# Cloud cover will be 75%
# UV will be 1 out of 12
# Wind speed will be 2.38 mph
# Visibility will be 4.61 miles
# Sun will rise at 06:40:44 and set at 17:55:45
#
# -----
# Forecast for Iron Goat Trail Snowshoe (Central Cascades) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/iron-goat-trail-snowshoe
#
# Hike is ; gains  feet; and has 0.00 out of 5 stars
# Drive will take 01:29:27 to cover 74.56 miles
# Foggy in the morning.
# High: will feel like 37.95 degrees F
# Low: will feel like 30.6 degrees F
# 31.0% chance of snow; maximum intensity at 17:00:00, with 0.92 inches of snow expected all day
# Cloud cover will be 76%
# UV will be 1 out of 12
# Wind speed will be 2.69 mph
# Visibility will be 4.94 miles
# Sun will rise at 06:40:13 and set at 17:55:11
#
# -----
# Forecast for Lake Twentytwo / Lake 22 Snowshoe (North Cascades) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/lake-twentytwo-snowshoe
#
# Hike is 5.0 miles, roundtrip; gains 1200 feet; and has 2.75 out of 5 stars
# Drive will take 01:11:06 to cover 56.30 miles
# Foggy in the morning.
# High: will feel like 41.12 degrees F
# Low: will feel like 32.18 degrees F
# 42.0% chance of snow; maximum intensity at 17:00:00, with 0.374 inches of snow expected all day
# Cloud cover will be 76%
# UV will be 1 out of 12
# Wind speed will be 2.98 mph
# Visibility will be 5.51 miles
# Sun will rise at 06:42:53 and set at 17:57:12
#
# -----
# Forecast for Dalles Ridge Snowshoe (Mount Rainier Area) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/dalles-ridge-snowshoe
#
# Hike is 8.0 miles, roundtrip; gains 1800 feet; and has 0.00 out of 5 stars
# Drive will take 01:27:36 to cover 65.16 miles
# Snow (1–2 in.) starting in the afternoon.
# High: will feel like 37.54 degrees F
# Low: will feel like 31.18 degrees F
# 36.0% chance of snow; maximum intensity at 17:00:00, with 1.177 inches of snow expected all day
# Cloud cover will be 78%
# UV will be 1 out of 12
# Wind speed will be 2.52 mph
# Visibility will be 6.62 miles
# Sun will rise at 06:41:23 and set at 17:57:25
#
# -----
# Forecast for Mount Margaret Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/mount-margaret-snowshoe
#
# Hike is 9.0 miles, roundtrip; gains 2800 feet; and has 3.00 out of 5 stars
# Drive will take 01:05:36 to cover 57.82 miles
# Snow (< 1 in.) overnight.
# High: will feel like 28.91 degrees F
# Low: will feel like 25.37 degrees F
# 32.0% chance of snow; maximum intensity at 17:00:00, with 1.282 inches of snow expected all day
# Cloud cover will be 78%
# UV will be 1 out of 12
# Wind speed will be 2.35 mph
# Visibility will be 5.71 miles
# Sun will rise at 06:40:43 and set at 17:56:16
#
# -----
# Forecast for Twin Lakes Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/twin-lakes-snowshoe
#
# Hike is 8.0 miles, roundtrip; gains 400 feet; and has 1.00 out of 5 stars
# Drive will take 00:58:04 to cover 54.57 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 36.51 degrees F
# Low: will feel like 31.72 degrees F
# 33.0% chance of snow; maximum intensity at 23:00:00, with 0.984 inches of snow expected all day
# Cloud cover will be 79%
# UV will be 1 out of 12
# Wind speed will be 2.29 mph
# Visibility will be 5.59 miles
# Sun will rise at 06:40:52 and set at 17:56:24
#
# -----
# Forecast for Lower Gold Creek Basin Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/lower-gold-creek-basin-snowshoe
#
# Hike is 4.0 miles, roundtrip; gains 400 feet; and has 3.44 out of 5 stars
# Drive will take 00:56:38 to cover 54.63 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 35.89 degrees F
# Low: will feel like 31.46 degrees F
# 33.0% chance of snow; maximum intensity at 17:00:00, with 0.996 inches of snow expected all day
# Cloud cover will be 80%
# UV will be 1 out of 12
# Wind speed will be 2.32 mph
# Visibility will be 5.53 miles
# Sun will rise at 06:40:49 and set at 17:56:20
#
# -----
# Forecast for Talapus Lake Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/talapus-lake-snowshoe
#
# Hike is 8.5 miles, roundtrip; gains 1600 feet; and has 3.00 out of 5 stars
# Drive will take 00:55:09 to cover 47.25 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 38.9 degrees F
# Low: will feel like 34 degrees F
# 36.0% chance of snow; maximum intensity at 23:00:00, with 0.871 inches of snow expected all day
# Cloud cover will be 80%
# UV will be 1 out of 12
# Wind speed will be 2.13 mph
# Visibility will be 5.72 miles
# Sun will rise at 06:41:24 and set at 17:56:54
#
# -----
# Forecast for Kendall Peak Lakes Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/kendall-peak-lakes-snowshoe
#
# Hike is 9.0 miles, roundtrip; gains 1700 feet; and has 4.12 out of 5 stars
# Drive will take 00:54:10 to cover 53.70 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 36.42 degrees F
# Low: will feel like 31.74 degrees F
# 34.0% chance of snow; maximum intensity at 23:00:00, with 1.008 inches of snow expected all day
# Cloud cover will be 81%
# UV will be 1 out of 12
# Wind speed will be 2.29 mph
# Visibility will be 5.45 miles
# Sun will rise at 06:40:53 and set at 17:56:24
#
# -----
# Forecast for Roaring Ridge Snowshoe via Road 9070 (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/roaring-ridge-snowshoe-via-road-9070
#
# Hike is 10.0 miles, roundtrip; gains 3200 feet; and has 0.00 out of 5 stars
# Drive will take 00:57:42 to cover 54.42 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 36.05 degrees F
# Low: will feel like 31.42 degrees F
# 34.0% chance of snow; maximum intensity at 23:00:00, with 1.001 inches of snow expected all day
# Cloud cover will be 81%
# UV will be 1 out of 12
# Wind speed will be 2.23 mph
# Visibility will be 5.54 miles
# Sun will rise at 06:40:53 and set at 17:56:25
#
# -----
# Forecast for Lake Keechelus Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/keechelus-lake-john-wayne
#
# Hike is 4.0 miles, roundtrip; gains 200 feet; and has 3.50 out of 5 stars
# Drive will take 00:55:43 to cover 54.14 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 36.68 degrees F
# Low: will feel like 31.89 degrees F
# 33.0% chance of snow; maximum intensity at 23:00:00, with 0.995 inches of snow expected all day
# Cloud cover will be 81%
# UV will be 1 out of 12
# Wind speed will be 2.23 mph
# Visibility will be 5.51 miles
# Sun will rise at 06:40:52 and set at 17:56:23
#
# -----
# Forecast for Surveyors Lake Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/surveyors-lake-snowshoe
#
# Hike is ; gains  feet; and has 0.00 out of 5 stars
# Drive will take 00:55:32 to cover 53.85 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 36.24 degrees F
# Low: will feel like 31.57 degrees F
# 33.0% chance of snow; maximum intensity at 23:00:00, with 1.005 inches of snow expected all day
# Cloud cover will be 81%
# UV will be 1 out of 12
# Wind speed will be 2.23 mph
# Visibility will be 5.52 miles
# Sun will rise at 06:40:53 and set at 17:56:24
#
# -----
# Forecast for Alaska Lake Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/alaska-lake-snowshoe
#
# Hike is 12.0 miles, roundtrip; gains 1600 feet; and has 3.33 out of 5 stars
# Drive will take 01:00:48 to cover 55.56 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 35.16 degrees F
# Low: will feel like 30.94 degrees F
# 33.0% chance of snow; maximum intensity at 17:00:00, with 1.029 inches of snow expected all day
# Cloud cover will be 81%
# UV will be 1 out of 12
# Wind speed will be 2.34 mph
# Visibility will be 5.41 miles
# Sun will rise at 06:40:48 and set at 17:56:18
#
# -----
# Forecast for Windy Pass - Mount Catherine Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/windy-pass-mount-catherine-snowshoe
#
# Hike is 9.0 miles, roundtrip; gains 2300 feet; and has 2.67 out of 5 stars
# Drive will take 00:54:46 to cover 53.86 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 35.69 degrees F
# Low: will feel like 31.22 degrees F
# 34.0% chance of snow; maximum intensity at 23:00:00, with 1.018 inches of snow expected all day
# Cloud cover will be 81%
# UV will be 1 out of 12
# Wind speed will be 2.27 mph
# Visibility will be 5.47 miles
# Sun will rise at 06:40:55 and set at 17:56:25
#
# -----
# Forecast for Granite Mountain Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/granite-mountain-snowshoe
#
# Hike is 5.0 miles, roundtrip; gains 3750 feet; and has 4.00 out of 5 stars
# Drive will take 00:49:03 to cover 47.02 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 39.81 degrees F
# Low: will feel like 34.68 degrees F
# 36.0% chance of snow; maximum intensity at 23:00:00, with 0.822 inches of snow expected all day
# Cloud cover will be 82%
# UV will be 1 out of 12
# Wind speed will be 2.11 mph
# Visibility will be 5.45 miles
# Sun will rise at 06:41:15 and set at 17:56:46
#
# -----
# Forecast for Olallie Mountain Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/olallie-mountain-snowshoe
#
# Hike is ; gains  feet; and has 0.00 out of 5 stars
# Drive will take 00:50:56 to cover 51.02 miles
# Snow (< 1 in.) overnight.
# High: will feel like 34.5 degrees F
# Low: will feel like 30.61 degrees F
# 35.0% chance of snow; maximum intensity at 23:00:00, with 1.084 inches of snow expected all day
# Cloud cover will be 83%
# UV will be 1 out of 12
# Wind speed will be 2.27 mph
# Visibility will be 5.19 miles
# Sun will rise at 06:40:59 and set at 17:56:27
#
# -----
# Forecast for Commonwealth Basin Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/commonwealth-basin-snowshoe
#
# Hike is 10.0 miles, roundtrip; gains 2300 feet; and has 3.71 out of 5 stars
# Drive will take 00:52:05 to cover 51.32 miles
# Snow (< 1 in.) overnight.
# High: will feel like 33.79 degrees F
# Low: will feel like 29.95 degrees F
# 35.0% chance of snow; maximum intensity at 23:00:00, with 1.102 inches of snow expected all day
# Cloud cover will be 84%
# UV will be 1 out of 12
# Wind speed will be 2.28 mph
# Visibility will be 5.18 miles
# Sun will rise at 06:40:59 and set at 17:56:26
#
# -----
# Forecast for Source Lake Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/source-lake-snowshoe
#
# Hike is 5.0 miles, roundtrip; gains 1000 feet; and has 3.40 out of 5 stars
# Drive will take 00:55:14 to cover 52.45 miles
# Snow (< 1 in.) overnight.
# High: will feel like 33.43 degrees F
# Low: will feel like 29.81 degrees F
# 36.0% chance of snow; maximum intensity at 23:00:00, with 1.143 inches of snow expected all day
# Cloud cover will be 85%
# UV will be 1 out of 12
# Wind speed will be 2.27 mph
# Visibility will be 5.02 miles
# Sun will rise at 06:41:02 and set at 17:56:28
#
# -----
# Forecast for Snow Lake Snowshoe (Snoqualmie Region) for Sun, Mar 04, 2018:
# https://www.wta.org/go-hiking/hikes/snow-lake-snowshoe
#
# Hike is 10.0 miles, roundtrip; gains 2000 feet; and has 4.25 out of 5 stars
# Drive will take 00:55:14 to cover 52.45 miles
# Light snow (< 1 in.) overnight.
# High: will feel like 34.13 degrees F
# Low: will feel like 29.83 degrees F
# 35.0% chance of snow; maximum intensity at 23:00:00, with 1.081 inches of snow expected all day
# Cloud cover will be 89%
# UV will be 1 out of 12
# Wind speed will be 2.45 mph
# Visibility will be 5.02 miles
# Sun will rise at 06:41:02 and set at 17:56:28
#
# -----
